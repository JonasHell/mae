# %%
from PIL import Image

p = "/mnt/embl/scratch/hellgoth/data/chlamy_slices_single_grey_224_down/240229_cw15-wtnew-wtold_interphase_nhs-tub-cetn-dna_cf_00/240229_cw15-wtnew-wtold_interphase_nhs-tub-cetn-dna_cf_00_chunksize-1-1276-1276_slc096.PNG"
img = Image.open(p)
print(img.size, img.mode)
img
# Out:
# (224, 224) L
# <PIL.PngImagePlugin.PngImageFile image mode=L size=224x224>

# %%
import numpy as np

a = np.array(img)
a.min(), a.max(), a.mean(), a.std(), a.shape, a.dtype
# Out:
# (0, 255, 27.274872448979593, 33.091206698483994, (224, 224), dtype('uint8'))

# %%
import matplotlib.pyplot as plt

plt.imshow(a, cmap='gray')
plt.show()

# %%
plt.imshow(a, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
a.mean(), a.std()
# Out:
# (27.274872448979593, 33.091206698483994)

# %%
b = (a-a.mean()) / a.std()
plt.imshow(b, cmap='gray')
plt.show()

# %%
b.min(), b.max(), b.mean(), b.std(), b.shape, b.dtype
# Out:
# (-0.8242332380773874,
#  6.881741413239342,
#  4.5315225494904345e-18,
#  1.0,
#  (224, 224),
#  dtype('float64'))

# %%
c = (a - 27.274872448979593) / 33.091206698483994
c.min(), c.max(), c.mean(), c.std(), c.shape, c.dtype
# Out:
# (-0.8242332380773874,
#  6.881741413239342,
#  4.5315225494904345e-18,
#  1.0,
#  (224, 224),
#  dtype('float64'))

# %%
from PIL import Image

p = "/mnt/embl/scratch/hellgoth/data/chlamy_slices_single_grey_224_down/240229_cw15-wtnew-wtold_interphase_nhs-tub-cetn-dna_cf_00/"
for i in range(200):
n = f"240229_cw15-wtnew-wtold_interphase_nhs-tub-cetn-dna_cf_00_chunksize-1-1276-1276_slc{i}.PNG"
img = Image.open(p)
print(img.size, img.mode)
img
